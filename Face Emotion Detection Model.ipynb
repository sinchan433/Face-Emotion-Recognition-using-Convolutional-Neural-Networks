# %%
# display some images for every different expression

import numpy as np
import seaborn as sns
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import os

# size of the image: 48*48 pixels
pic_size = 48

# input path for the images
base_path = "../input/face-expression-recognition-dataset/images/"

plt.figure(0, figsize=(12,20))
cpt = 0

for expression in os.listdir(base_path + "train"):
    for i in range(1,6):
        cpt = cpt + 1
        plt.subplot(7,5,cpt)
        img = load_img(base_path + "train/" + expression + "/" +os.listdir(base_path + "train/" + expression)[i], target_size=(pic_size, pic_size))
        plt.imshow(img, cmap="gray")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Image augmentation using keras ImageDataGenerator

# %%
# building data generator 

from keras.preprocessing.image import ImageDataGenerator

batch_size = 128
base_path = "../input/face-expression-recognition-dataset/images/"


train_datagen = ImageDataGenerator(rescale = 1.0/255.0,
                                  width_shift_range = 0.1,
                                   height_shift_range = 0.1,
                                   rotation_range = 20,
                                   horizontal_flip = True)

validation_datagen = ImageDataGenerator(rescale= 1.0/255)

train_generator = train_datagen.flow_from_directory(base_path + "train",
                                                    target_size=(56,56),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=True)

validation_generator = validation_datagen.flow_from_directory(base_path + "validation",
                                                    target_size=(56,56),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=False)
# Out:
# Found 28821 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.

# %% [markdown]
# # Defining our 4 Convolution and 2 Dense layers model

# %%
from keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D, Flatten, Conv2D, BatchNormalization, Activation, MaxPooling2D
from keras.models import Model, Sequential
from keras.optimizers import Adam

# number of possible label values
nb_classes = 7

# Initialising the CNN
model = Sequential()

# 1 - Convolution
model.add(Conv2D(64,(3,3), padding='same', input_shape=(56, 56,1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 2nd Convolution layer
model.add(Conv2D(128,(5,5), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 3rd Convolution layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 4th Convolution layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Flattening
model.add(Flatten())

# Fully connected layer 1st layer
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

# Fully connected layer 2nd layer
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(nb_classes, activation='softmax'))

print(model.summary())

opt = Adam(lr=0.0001)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 56, 56, 64)        640
# _________________________________________________________________
# batch_normalization (BatchNo (None, 56, 56, 64)        256
# _________________________________________________________________
# activation (Activation)      (None, 56, 56, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 128)       204928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_1 (Activation)    (None, 28, 28, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 512)       590336
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 14, 14, 512)       2048
# _________________________________________________________________
# activation_2 (Activation)    (None, 14, 14, 512)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 512)         2359808
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_3 (Activation)    (None, 7, 7, 512)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               1179904
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_4 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               131584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 3591
# =================================================================
# Total params: 4,478,727
# Trainable params: 4,474,759
# Non-trainable params: 3,968
# _________________________________________________________________
# None

# %%
# %%time

# number of epochs to train the NN
epochs = 50

# checkpoint to save best model
from keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint("model_weights.h5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit_generator(generator=train_generator,
                                steps_per_epoch=train_generator.n//train_generator.batch_size,
                                epochs=epochs,
                                validation_data = validation_generator,
                                validation_steps = validation_generator.n//validation_generator.batch_size,
                                callbacks=callbacks_list
                                )
# Out:
# Epoch 1/50
# 225/225 [==============================] - ETA: 0s - loss: 2.0383 - accuracy: 0.2179
# Epoch 00001: val_accuracy improved from -inf to 0.17273, saving model to model_weights.h5
# 225/225 [==============================] - 96s 426ms/step - loss: 2.0383 - accuracy: 0.2179 - val_loss: 1.8595 - val_accuracy: 0.1727
# Epoch 2/50
# 225/225 [==============================] - ETA: 0s - loss: 1.9034 - accuracy: 0.2432
# Epoch 00002: val_accuracy improved from 0.17273 to 0.18580, saving model to model_weights.h5
# 225/225 [==============================] - 41s 184ms/step - loss: 1.9034 - accuracy: 0.2432 - val_loss: 1.8809 - val_accuracy: 0.1858
# Epoch 3/50
# 225/225 [==============================] - ETA: 0s - loss: 1.8596 - accuracy: 0.2599
# Epoch 00003: val_accuracy improved from 0.18580 to 0.28821, saving model to model_weights.h5
# 225/225 [==============================] - 43s 191ms/step - loss: 1.8596 - accuracy: 0.2599 - val_loss: 1.7705 - val_accuracy: 0.2882
# Epoch 4/50
# 225/225 [==============================] - ETA: 0s - loss: 1.8173 - accuracy: 0.2792
# Epoch 00004: val_accuracy improved from 0.28821 to 0.31520, saving model to model_weights.h5
# 225/225 [==============================] - 42s 185ms/step - loss: 1.8173 - accuracy: 0.2792 - val_loss: 1.7586 - val_accuracy: 0.3152
# Epoch 5/50
# 225/225 [==============================] - ETA: 0s - loss: 1.7660 - accuracy: 0.3037
# Epoch 00005: val_accuracy improved from 0.31520 to 0.35270, saving model to model_weights.h5
# 225/225 [==============================] - 40s 179ms/step - loss: 1.7660 - accuracy: 0.3037 - val_loss: 1.7173 - val_accuracy: 0.3527
# Epoch 6/50
# 225/225 [==============================] - ETA: 0s - loss: 1.7232 - accuracy: 0.3236
# Epoch 00006: val_accuracy did not improve from 0.35270
# 225/225 [==============================] - 41s 184ms/step - loss: 1.7232 - accuracy: 0.3236 - val_loss: 1.8073 - val_accuracy: 0.3514
# Epoch 7/50
# 225/225 [==============================] - ETA: 0s - loss: 1.6745 - accuracy: 0.3444
# Epoch 00007: val_accuracy improved from 0.35270 to 0.40256, saving model to model_weights.h5
# 225/225 [==============================] - 41s 184ms/step - loss: 1.6745 - accuracy: 0.3444 - val_loss: 1.5976 - val_accuracy: 0.4026
# Epoch 8/50
# 225/225 [==============================] - ETA: 0s - loss: 1.6389 - accuracy: 0.3585
# Epoch 00008: val_accuracy improved from 0.40256 to 0.40483, saving model to model_weights.h5
# 225/225 [==============================] - 42s 188ms/step - loss: 1.6389 - accuracy: 0.3585 - val_loss: 1.5948 - val_accuracy: 0.4048
# Epoch 9/50
# 225/225 [==============================] - ETA: 0s - loss: 1.5997 - accuracy: 0.3780
# Epoch 00009: val_accuracy improved from 0.40483 to 0.43111, saving model to model_weights.h5
# 225/225 [==============================] - 41s 181ms/step - loss: 1.5997 - accuracy: 0.3780 - val_loss: 1.4922 - val_accuracy: 0.4311
# Epoch 10/50
# 225/225 [==============================] - ETA: 0s - loss: 1.5679 - accuracy: 0.3895
# Epoch 00010: val_accuracy improved from 0.43111 to 0.43594, saving model to model_weights.h5
# 225/225 [==============================] - 43s 191ms/step - loss: 1.5679 - accuracy: 0.3895 - val_loss: 1.4496 - val_accuracy: 0.4359
# Epoch 11/50
# 225/225 [==============================] - ETA: 0s - loss: 1.5337 - accuracy: 0.4033
# Epoch 00011: val_accuracy did not improve from 0.43594
# 225/225 [==============================] - 42s 188ms/step - loss: 1.5337 - accuracy: 0.4033 - val_loss: 1.5370 - val_accuracy: 0.4352
# Epoch 12/50
# 225/225 [==============================] - ETA: 0s - loss: 1.5055 - accuracy: 0.4172
# Epoch 00012: val_accuracy improved from 0.43594 to 0.45781, saving model to model_weights.h5
# 225/225 [==============================] - 41s 184ms/step - loss: 1.5055 - accuracy: 0.4172 - val_loss: 1.4082 - val_accuracy: 0.4578
# Epoch 13/50
# 225/225 [==============================] - ETA: 0s - loss: 1.4737 - accuracy: 0.4276
# Epoch 00013: val_accuracy did not improve from 0.45781
# 225/225 [==============================] - 42s 187ms/step - loss: 1.4737 - accuracy: 0.4276 - val_loss: 1.5182 - val_accuracy: 0.4479
# Epoch 14/50
# 225/225 [==============================] - ETA: 0s - loss: 1.4564 - accuracy: 0.4386
# Epoch 00014: val_accuracy improved from 0.45781 to 0.48523, saving model to model_weights.h5
# 225/225 [==============================] - 42s 185ms/step - loss: 1.4564 - accuracy: 0.4386 - val_loss: 1.3324 - val_accuracy: 0.4852
# Epoch 15/50
# 225/225 [==============================] - ETA: 0s - loss: 1.4273 - accuracy: 0.4504
# Epoch 00015: val_accuracy improved from 0.48523 to 0.50639, saving model to model_weights.h5
# 225/225 [==============================] - 42s 185ms/step - loss: 1.4273 - accuracy: 0.4504 - val_loss: 1.3196 - val_accuracy: 0.5064
# Epoch 16/50
# 225/225 [==============================] - ETA: 0s - loss: 1.3947 - accuracy: 0.4612
# Epoch 00016: val_accuracy improved from 0.50639 to 0.51818, saving model to model_weights.h5
# 225/225 [==============================] - 42s 188ms/step - loss: 1.3947 - accuracy: 0.4612 - val_loss: 1.2659 - val_accuracy: 0.5182
# Epoch 17/50
# 225/225 [==============================] - ETA: 0s - loss: 1.3752 - accuracy: 0.4711
# Epoch 00017: val_accuracy improved from 0.51818 to 0.53125, saving model to model_weights.h5
# 225/225 [==============================] - 43s 190ms/step - loss: 1.3752 - accuracy: 0.4711 - val_loss: 1.2352 - val_accuracy: 0.5312
# Epoch 18/50
# 225/225 [==============================] - ETA: 0s - loss: 1.3554 - accuracy: 0.4800
# Epoch 00018: val_accuracy improved from 0.53125 to 0.53153, saving model to model_weights.h5
# 225/225 [==============================] - 44s 194ms/step - loss: 1.3554 - accuracy: 0.4800 - val_loss: 1.2250 - val_accuracy: 0.5315
# Epoch 19/50
# 225/225 [==============================] - ETA: 0s - loss: 1.3335 - accuracy: 0.4903
# Epoch 00019: val_accuracy improved from 0.53153 to 0.53310, saving model to model_weights.h5
# 225/225 [==============================] - 44s 196ms/step - loss: 1.3335 - accuracy: 0.4903 - val_loss: 1.2243 - val_accuracy: 0.5331
# Epoch 20/50
# 225/225 [==============================] - ETA: 0s - loss: 1.3201 - accuracy: 0.4916
# Epoch 00020: val_accuracy did not improve from 0.53310
# 225/225 [==============================] - 42s 189ms/step - loss: 1.3201 - accuracy: 0.4916 - val_loss: 1.2864 - val_accuracy: 0.5074
# Epoch 21/50
# 225/225 [==============================] - ETA: 0s - loss: 1.3119 - accuracy: 0.4966
# Epoch 00021: val_accuracy improved from 0.53310 to 0.55256, saving model to model_weights.h5
# 225/225 [==============================] - 42s 187ms/step - loss: 1.3119 - accuracy: 0.4966 - val_loss: 1.1826 - val_accuracy: 0.5526
# Epoch 22/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2934 - accuracy: 0.5026
# Epoch 00022: val_accuracy improved from 0.55256 to 0.55810, saving model to model_weights.h5
# 225/225 [==============================] - 41s 184ms/step - loss: 1.2934 - accuracy: 0.5026 - val_loss: 1.1772 - val_accuracy: 0.5581
# Epoch 23/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2746 - accuracy: 0.5104
# Epoch 00023: val_accuracy did not improve from 0.55810
# 225/225 [==============================] - 42s 187ms/step - loss: 1.2746 - accuracy: 0.5104 - val_loss: 1.1836 - val_accuracy: 0.5499
# Epoch 24/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2701 - accuracy: 0.5158
# Epoch 00024: val_accuracy did not improve from 0.55810
# 225/225 [==============================] - 41s 184ms/step - loss: 1.2701 - accuracy: 0.5158 - val_loss: 1.1678 - val_accuracy: 0.5516
# Epoch 25/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2519 - accuracy: 0.5215
# Epoch 00025: val_accuracy improved from 0.55810 to 0.56080, saving model to model_weights.h5
# 225/225 [==============================] - 42s 189ms/step - loss: 1.2519 - accuracy: 0.5215 - val_loss: 1.1542 - val_accuracy: 0.5608
# Epoch 26/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2471 - accuracy: 0.5228
# Epoch 00026: val_accuracy improved from 0.56080 to 0.56648, saving model to model_weights.h5
# 225/225 [==============================] - 41s 180ms/step - loss: 1.2471 - accuracy: 0.5228 - val_loss: 1.1476 - val_accuracy: 0.5665
# Epoch 27/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2305 - accuracy: 0.5274
# Epoch 00027: val_accuracy improved from 0.56648 to 0.57301, saving model to model_weights.h5
# 225/225 [==============================] - 43s 189ms/step - loss: 1.2305 - accuracy: 0.5274 - val_loss: 1.1248 - val_accuracy: 0.5730
# Epoch 28/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2169 - accuracy: 0.5331
# Epoch 00028: val_accuracy did not improve from 0.57301
# 225/225 [==============================] - 43s 192ms/step - loss: 1.2169 - accuracy: 0.5331 - val_loss: 1.1566 - val_accuracy: 0.5615
# Epoch 29/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2092 - accuracy: 0.5357
# Epoch 00029: val_accuracy improved from 0.57301 to 0.58565, saving model to model_weights.h5
# 225/225 [==============================] - 43s 191ms/step - loss: 1.2092 - accuracy: 0.5357 - val_loss: 1.1030 - val_accuracy: 0.5857
# Epoch 30/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2066 - accuracy: 0.5380
# Epoch 00030: val_accuracy did not improve from 0.58565
# 225/225 [==============================] - 43s 189ms/step - loss: 1.2066 - accuracy: 0.5380 - val_loss: 1.1500 - val_accuracy: 0.5608
# Epoch 31/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1920 - accuracy: 0.5439
# Epoch 00031: val_accuracy did not improve from 0.58565
# 225/225 [==============================] - 42s 188ms/step - loss: 1.1920 - accuracy: 0.5439 - val_loss: 1.1385 - val_accuracy: 0.5656
# Epoch 32/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1844 - accuracy: 0.5472
# Epoch 00032: val_accuracy did not improve from 0.58565
# 225/225 [==============================] - 42s 188ms/step - loss: 1.1844 - accuracy: 0.5472 - val_loss: 1.1259 - val_accuracy: 0.5670
# Epoch 33/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1726 - accuracy: 0.5564
# Epoch 00033: val_accuracy improved from 0.58565 to 0.59176, saving model to model_weights.h5
# 225/225 [==============================] - 42s 187ms/step - loss: 1.1726 - accuracy: 0.5564 - val_loss: 1.0768 - val_accuracy: 0.5918
# Epoch 34/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1718 - accuracy: 0.5543
# Epoch 00034: val_accuracy improved from 0.59176 to 0.60923, saving model to model_weights.h5
# 225/225 [==============================] - 43s 190ms/step - loss: 1.1718 - accuracy: 0.5543 - val_loss: 1.0414 - val_accuracy: 0.6092
# Epoch 35/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1586 - accuracy: 0.5594
# Epoch 00035: val_accuracy did not improve from 0.60923
# 225/225 [==============================] - 42s 186ms/step - loss: 1.1586 - accuracy: 0.5594 - val_loss: 1.0437 - val_accuracy: 0.6080
# Epoch 36/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1556 - accuracy: 0.5588
# Epoch 00036: val_accuracy did not improve from 0.60923
# 225/225 [==============================] - 41s 183ms/step - loss: 1.1556 - accuracy: 0.5588 - val_loss: 1.0735 - val_accuracy: 0.5960
# Epoch 37/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1488 - accuracy: 0.5642
# Epoch 00037: val_accuracy did not improve from 0.60923
# 225/225 [==============================] - 42s 186ms/step - loss: 1.1488 - accuracy: 0.5642 - val_loss: 1.0680 - val_accuracy: 0.5962
# Epoch 38/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1357 - accuracy: 0.5666
# Epoch 00038: val_accuracy did not improve from 0.60923
# 225/225 [==============================] - 42s 187ms/step - loss: 1.1357 - accuracy: 0.5666 - val_loss: 1.0850 - val_accuracy: 0.5861
# Epoch 39/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1356 - accuracy: 0.5666
# Epoch 00039: val_accuracy did not improve from 0.60923
# 225/225 [==============================] - 41s 184ms/step - loss: 1.1356 - accuracy: 0.5666 - val_loss: 1.0847 - val_accuracy: 0.5896
# Epoch 40/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1229 - accuracy: 0.5720
# Epoch 00040: val_accuracy did not improve from 0.60923
# 225/225 [==============================] - 42s 188ms/step - loss: 1.1229 - accuracy: 0.5720 - val_loss: 1.1213 - val_accuracy: 0.5747
# Epoch 41/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1215 - accuracy: 0.5752
# Epoch 00041: val_accuracy did not improve from 0.60923
# 225/225 [==============================] - 41s 184ms/step - loss: 1.1215 - accuracy: 0.5752 - val_loss: 1.0606 - val_accuracy: 0.6001
# Epoch 42/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1164 - accuracy: 0.5735
# Epoch 00042: val_accuracy did not improve from 0.60923
# 225/225 [==============================] - 41s 181ms/step - loss: 1.1164 - accuracy: 0.5735 - val_loss: 1.0864 - val_accuracy: 0.5882
# Epoch 43/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1082 - accuracy: 0.5766
# Epoch 00043: val_accuracy did not improve from 0.60923
# 225/225 [==============================] - 41s 184ms/step - loss: 1.1082 - accuracy: 0.5766 - val_loss: 1.0323 - val_accuracy: 0.6075
# Epoch 44/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1044 - accuracy: 0.5812
# Epoch 00044: val_accuracy did not improve from 0.60923
# 225/225 [==============================] - 42s 188ms/step - loss: 1.1044 - accuracy: 0.5812 - val_loss: 1.0921 - val_accuracy: 0.5857
# Epoch 45/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1015 - accuracy: 0.5805
# Epoch 00045: val_accuracy did not improve from 0.60923
# 225/225 [==============================] - 43s 190ms/step - loss: 1.1015 - accuracy: 0.5805 - val_loss: 1.0601 - val_accuracy: 0.5986
# Epoch 46/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0940 - accuracy: 0.5821
# Epoch 00046: val_accuracy did not improve from 0.60923
# 225/225 [==============================] - 41s 183ms/step - loss: 1.0940 - accuracy: 0.5821 - val_loss: 1.1559 - val_accuracy: 0.5753
# Epoch 47/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0875 - accuracy: 0.5861
# Epoch 00047: val_accuracy did not improve from 0.60923
# 225/225 [==============================] - 42s 185ms/step - loss: 1.0875 - accuracy: 0.5861 - val_loss: 1.0495 - val_accuracy: 0.5999
# Epoch 48/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0834 - accuracy: 0.5847
# Epoch 00048: val_accuracy improved from 0.60923 to 0.61690, saving model to model_weights.h5
# 225/225 [==============================] - 41s 180ms/step - loss: 1.0834 - accuracy: 0.5847 - val_loss: 1.0185 - val_accuracy: 0.6169
# Epoch 49/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0759 - accuracy: 0.5906
# Epoch 00049: val_accuracy improved from 0.61690 to 0.61875, saving model to model_weights.h5
# 225/225 [==============================] - 39s 176ms/step - loss: 1.0759 - accuracy: 0.5906 - val_loss: 1.0148 - val_accuracy: 0.6187
# Epoch 50/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0644 - accuracy: 0.5921
# Epoch 00050: val_accuracy did not improve from 0.61875
# 225/225 [==============================] - 40s 179ms/step - loss: 1.0644 - accuracy: 0.5921 - val_loss: 1.1049 - val_accuracy: 0.5791
# CPU times: user 27min 31s, sys: 3min 39s, total: 31min 10s
# Wall time: 36min 4s

# %%
# visualise training and testing accuracy and loss

def plot_results(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    plt.figure(figsize = (24, 6))
    plt.subplot(1,2,1)
    plt.plot(epochs, acc, 'b', label = 'Training Accuracy')
    plt.plot(epochs, val_acc, 'r', label = 'Validation Accuracy')
    plt.grid(True)
    plt.legend()
    plt.xlabel('Epoch')
    


    plt.subplot(1,2,2)
    plt.plot(epochs, loss, 'b', label = 'Training Loss')
    plt.plot(epochs, val_loss, 'r', label = 'Validation Loss')
    plt.grid(True)
    plt.legend()
    plt.xlabel('Epoch')
    plt.show()
 
# print best epoch with best accuracy on validation

def get_best_epcoh(history):
    valid_acc = history.history['val_accuracy']
    best_epoch = valid_acc.index(max(valid_acc)) + 1
    best_acc =  max(valid_acc)
    print('Best Validation Accuracy Score {:0.5f}, is for epoch {}'.format( best_acc, best_epoch))
    return best_epoch

# %%
plot_results(history)
best_epoch =get_best_epcoh(history)
# Out:
# Best Validation Accuracy Score 0.61875, is for epoch 49
